# %%
import pandas as pd
import numpy as np

# %%
movies =pd.read_csv('Dataset/imdb-top-1000.csv')

# %%
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
movies.shape
# Out:
# (1000, 10)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
# Series_Title     1000 non-null object
# Released_Year    1000 non-null object
# Runtime          1000 non-null int64
# Genre            1000 non-null object
# IMDB_Rating      1000 non-null float64
# Director         1000 non-null object
# Star1            1000 non-null object
# No_of_Votes      1000 non-null int64
# Gross            1000 non-null float64
# Metascore        843 non-null float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.2+ KB

# %%
movies['Genre'].value_counts()
# Out:
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Fantasy        2
# Family         2
# Thriller       1
# Name: Genre, dtype: int64

# %%
movies.groupby('Genre')

# %%
movies[movies['Genre']=='Action']
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# ..                                                 ...           ...      ...
# 968                                       Falling Down          1993      113
# 979                                      Lethal Weapon          1987      109
# 982                                          Mad Max 2          1981       96
# 983                                       The Warriors          1979       92
# 985                               Escape from Alcatraz          1979      112
#
# ...

# %%
movies[movies['Genre']=='Comedy']
# Out:
#                                        Series_Title Released_Year  Runtime  \
# 19                                     Gisaengchung          2019      132
# 26                                  La vita è bella          1997      116
# 51                                     Modern Times          1936       87
# 52                                      City Lights          1931       87
# 64                                         3 Idiots          2009      170
# ..                                              ...           ...      ...
# 977  The Naked Gun: From the Files of Police Squad!          1988       85
# 978                    Planes, Trains & Automobiles          1987       93
# 989                                The Long Goodbye          1973      112
# 994                              A Hard Day's Night          1964       87
# 995                          Breakfast at Tiffany's          1961      115
#
# ...

# %%
movies.groupby('Genre')

# %%
movies.groupby('Genre').groups
# Out:
# {'Action': Int64Index([  2,   5,   8,  10,  13,  14,  16,  29,  30,  31,
#              ...
#              930, 931, 944, 951, 963, 968, 979, 982, 983, 985],
#             dtype='int64', length=172),
#  'Adventure': Int64Index([ 21,  47,  93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209,
#              226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361,
#              366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514,
#              537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681,
#              686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912,
#              919, 947, 957, 964, 966, 984, 991],
#             dtype='int64'),
#  'Animation': Int64Index([ 23,  43,  46,  56,  58,  61,  66,  70, 101, 135, 146, 151, 158,
#              170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 330,
#              332, 358, 367, 378, 386, 389, 394, 395, 399, 401, 405, 409, 469,
# ...

# %%
movies.groupby('Genre').get_group('Crime')
# Out:
#                 Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 1              The Godfather          1972      175  Crime          9.2
# 3     The Godfather: Part II          1974      202  Crime          9.0
# 4               12 Angry Men          1957       96  Crime          9.0
# 6               Pulp Fiction          1994      154  Crime          8.9
# 22            Cidade de Deus          2002      130  Crime          8.6
# ..                       ...           ...      ...    ...          ...
# 958              Funny Games          1997      108  Crime          7.6
# 960                 Sleepers          1996      147  Crime          7.6
# 974  The Godfather: Part III          1990      162  Crime          7.6
# 980             Blood Simple          1984       99  Crime          7.6
# 999             The 39 Steps          1935       86  Crime          7.6
#
#                  Director           Star1  No_of_Votes        Gross  Metascore
# ...

# %%
movies.groupby('Genre').get_group('Family')
# Out:
#                             Series_Title Released_Year  Runtime   Genre  \
# 688           E.T. the Extra-Terrestrial          1982      115  Family
# 698  Willy Wonka & the Chocolate Factory          1971      100  Family
#
#      IMDB_Rating          Director         Star1  No_of_Votes        Gross  \
# 688          7.8  Steven Spielberg  Henry Thomas       372490  435110554.0
# 698          7.8        Mel Stuart   Gene Wilder       178731    4000000.0
#
#      Metascore
# 688       91.0
# 698       67.0

# %%
movies.groupby('Genre').get_group('Western')
# Out:
#                         Series_Title Released_Year  Runtime    Genre  \
# 12   Il buono, il brutto, il cattivo          1966      161  Western
# 48      Once Upon a Time in the West          1968      165  Western
# 115       Per qualche dollaro in più          1965      132  Western
# 691           The Outlaw Josey Wales          1976      135  Western
#
#      IMDB_Rating        Director           Star1  No_of_Votes       Gross  \
# 12           8.8    Sergio Leone  Clint Eastwood       688390   6100000.0
# 48           8.5    Sergio Leone     Henry Fonda       302844   5321508.0
# 115          8.3    Sergio Leone  Clint Eastwood       232772  15000000.0
# 691          7.8  Clint Eastwood  Clint Eastwood        65659  31800000.0
#
#      Metascore
# 12        90.0
# 48        80.0
# 115       74.0
# 691       69.0

# %%
movies.groupby('Genre')['IMDB_Rating'].mean().sort_values()
# Out:
# Genre
# Family       7.800000
# Thriller     7.800000
# Comedy       7.901290
# Horror       7.909091
# Animation    7.930488
# Adventure    7.937500
# Biography    7.938636
# Action       7.949419
# Drama        7.957439
# Film-Noir    7.966667
# Mystery      7.975000
# Fantasy      8.000000
# Crime        8.016822
# Western      8.350000
# Name: IMDB_Rating, dtype: float64

# %%
movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending = False)
# Out:
# Genre
# Western      8.350000
# Crime        8.016822
# Fantasy      8.000000
# Mystery      7.975000
# Film-Noir    7.966667
# Drama        7.957439
# Action       7.949419
# Biography    7.938636
# Adventure    7.937500
# Animation    7.930488
# Horror       7.909091
# Comedy       7.901290
# Thriller     7.800000
# Family       7.800000
# Name: IMDB_Rating, dtype: float64

# %%
# Find a movie having higher rating
movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending = False).index[0]
# Out:
# 'Western'

# %%
# Find a movie having lower rating
movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending = False).index[-1]
# Out:
# 'Family'

# %%
movies[movies.Released_Year=="1994"]
# Out:
#                  Series_Title Released_Year  Runtime      Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142      Drama          9.3
# 6                Pulp Fiction          1994      154      Crime          8.9
# 11               Forrest Gump          1994      142      Drama          8.8
# 42                       Léon          1994      110     Action          8.5
# 43              The Lion King          1994       88  Animation          8.5
# 166           Andaz Apna Apna          1994      160     Action          8.2
# 260     Trois couleurs: Rouge          1994       99      Drama          8.1
# 261        Chung Hing sam lam          1994      102     Comedy          8.1
# 519        Once Were Warriors          1994      102      Crime          7.9
# 657                   Ed Wood          1994      127  Biography          7.8
# 815                Il postino          1994      108  Biography          7.7
# ...

# %%
movies.groupby('Series_Title')['Runtime'].max().sort_values(ascending = False)
# Out:
# Series_Title
# Gangs of Wasseypur             321
# Hamlet                         242
# Gone with the Wind             238
# Once Upon a Time in America    229
# Lawrence of Arabia             228
#                               ...
# Duck Soup                       69
# The Kid                         68
# The General                     67
# Freaks                          64
# Sherlock Jr.                    45
# Name: Runtime, Length: 999, dtype: int64

# %%
movies.groupby('Genre')['No_of_Votes'].sum()
# Out:
# Genre
# Action       72282412
# Adventure    22576163
# Animation    21978630
# Biography    24006844
# Comedy       27620327
# Crime        33533615
# Drama        61367304
# Family         551221
# Fantasy        146222
# Film-Noir      367215
# Horror        3742556
# Mystery       4203004
# Thriller        27733
# Western       1289665
# Name: No_of_Votes, dtype: int64

# %%
movies.groupby('Genre')['No_of_Votes'].sum().sort_values(ascending = False).index[0:3]
# Out:
# Index(['Action', 'Drama', 'Crime'], dtype='object', name='Genre')

# %%
movies.groupby('Genre')['No_of_Votes'].sum().sort_values(ascending = False).index[-4:-1]
# Out:
# Index(['Family', 'Film-Noir', 'Fantasy'], dtype='object', name='Genre')

# %%
movies.groupby('Released_Year')['Runtime'].sum()
# Out:
# Released_Year
# 1920      76
# 1921      68
# 1922      94
# 1924      45
# 1925     170
#         ...
# 2017    2675
# 2018    2434
# 2019    3039
# 2020     760
# PG       140
# Name: Runtime, Length: 100, dtype: int64

# %%
movies.groupby('Released_Year')['Runtime'].sum().sort_values(ascending = False).index[0:3]
# Out:
# Index(['2014', '2004', '2013'], dtype='object', name='Released_Year')

# %%
movies.groupby('Director')['Gross'].max().sort_values(ascending = False).head(3)
# Out:
# Director
# J.J. Abrams      936662225.0
# Ramesh Sippy     932069480.0
# Dennis Gansel    924558264.0
# Name: Gross, dtype: float64

# %%
movies.groupby('Director')['Gross'].sum().sort_values(ascending = False).index[0]
# Out:
# 'Akira Kurosawa'

# %%
movies.groupby('Director')['Gross'].sum().sort_values(ascending = False).index[0:3]
# Out:
# Index(['Akira Kurosawa', 'Steven Spielberg', 'Hayao Miyazaki'], dtype='object', name='Director')

# %%
movies[movies.Genre =='Action']
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# ..                                                 ...           ...      ...
# 968                                       Falling Down          1993      113
# 979                                      Lethal Weapon          1987      109
# 982                                          Mad Max 2          1981       96
# 983                                       The Warriors          1979       92
# 985                               Escape from Alcatraz          1979      112
#
# ...

# %%
movies[movies.Genre =='Action'].groupby('Star1')['Star1'].count().sort_values(ascending = False).head(3)
# Out:
# Star1
# Harrison Ford    5
# Joe Russo        4
# Tom Cruise       4
# Name: Star1, dtype: int64

# %%
movies.groupby('Series_Title')['Runtime'].max().sort_values(ascending = False).head(3)
# Out:
# Series_Title
# Gangs of Wasseypur    321
# Hamlet                242
# Gone with the Wind    238
# Name: Runtime, dtype: int64

# %%
movies.sort_values(by = 'Runtime', ascending = False).head(3)['Series_Title']
# Out:
# 140    Gangs of Wasseypur
# 812                Hamlet
# 314    Gone with the Wind
# Name: Series_Title, dtype: object
