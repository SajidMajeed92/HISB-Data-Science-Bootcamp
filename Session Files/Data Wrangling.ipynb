# %%
import numpy as np
import pandas as pd

# %%
sheet0 = pd.read_excel('Dataset/test_data.xlsx' ,sheet_name = 0)
sheet1 = pd.read_excel('Dataset/test_data.xlsx' ,sheet_name = 1 ,header = None)
sheet2 = pd.read_excel('Dataset/test_data.xlsx' ,sheet_name = 2)
sheet3 = pd.read_excel('Dataset/test_data.xlsx' ,sheet_name = 3)

# %%
sheet0
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
sheet1
# Out:
#          0  1    2       3
# 0     Asad  A  100  100000
# 1  Hussain  B  300  450000
# 2      Ali  C  234  125000
# 3     Sana  D  231  652000
# 4  Fatima   E  324  145000
# 5   Kashif  F  123  825000
# 6   Hassan  G  129  125000
# 7    Almas  H  345  325600
# 8    Fahan  I  400  895200

# %%
sheet2
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             2          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2             3        Huzaifa        Karachi         145   Najam
# 3             4           Asad         Lahore         567   Najam
# 4             5        Hussain      Hyderabad         234   Jawed
# 5            66            Ali      Hyderabad         234  Faisal
# 6            77          Sadaf         Lahore         567  Faisal
# 7            88          Kiran        Karachi         345   Najam
# 8            99            Ali        Karachi         123  Faisal

# %%
sheet3
# Out:
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1        Hussain       B    300   450000
# 2            Ali       C    234   125000
# 3           Sana       D    231   652000
# 4         Fatima       E    324   145000
# 5         Kashif       F    123   825000
# 6         Hassan       G    129   125000
# 7          Almas       H    345   325600
# 8          Fahan       I    400   895200

# %%
new_sheet = pd.concat([sheet0,sheet2])
new_sheet.reset_index(drop=True ,inplace =True)
new_sheet
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager
# 0              1           Asad        Karachi         123   Jawed
# 1              2         Sumair         Lahore         123   Jawed
# 2              3         Farjad        Karachi         145   Najam
# 3              4         Hassan         Lahore         567   Najam
# 4              5          Nasir      Hyderabad         234   Jawed
# 5              6         Kashif      Hyderabad         234  Faisal
# 6              7           Sana         Lahore         567  Faisal
# 7              8         Fatima        Karachi         345   Najam
# 8              9       Abdullah        Karachi         123  Faisal
# 9              2          Ahmed        Karachi         123   Jawed
# 10            22           Umer         Lahore         123   Jawed
# 11             3        Huzaifa        Karachi         145   Najam
# 12             4           Asad         Lahore         567   Najam
# ...

# %%
pd.concat([sheet0,sheet3])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#     Amount  Region   Sales manager  product_id sales_man_city  sales_man_id  \
# 0       NaN     NaN    NaN   Jawed       123.0        Karachi           1.0
# 1       NaN     NaN    NaN   Jawed       123.0         Lahore           2.0
# 2       NaN     NaN    NaN   Najam       145.0        Karachi           3.0
# 3       NaN     NaN    NaN   Najam       567.0         Lahore           4.0
# 4       NaN     NaN    NaN   Jawed       234.0      Hyderabad           5.0
# 5       NaN     NaN    NaN  Faisal       234.0      Hyderabad           6.0
# ...

# %%
pd.concat([sheet1,sheet3])
# Out:
#          0    1      2         3   Amount  Region   Sales sales_man_name
# 0     Asad    A  100.0  100000.0       NaN     NaN    NaN            NaN
# 1  Hussain    B  300.0  450000.0       NaN     NaN    NaN            NaN
# 2      Ali    C  234.0  125000.0       NaN     NaN    NaN            NaN
# 3     Sana    D  231.0  652000.0       NaN     NaN    NaN            NaN
# 4  Fatima     E  324.0  145000.0       NaN     NaN    NaN            NaN
# 5   Kashif    F  123.0  825000.0       NaN     NaN    NaN            NaN
# 6   Hassan    G  129.0  125000.0       NaN     NaN    NaN            NaN
# 7    Almas    H  345.0  325600.0       NaN     NaN    NaN            NaN
# 8    Fahan    I  400.0  895200.0       NaN     NaN    NaN            NaN
# 0      NaN  NaN    NaN       NaN  100000.0       A  100.0           Asad
# 1      NaN  NaN    NaN       NaN  450000.0       B  300.0        Hussain
# 2      NaN  NaN    NaN       NaN  125000.0       C  234.0            Ali
# ...

# %%
sheet0
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
sheet2
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             2          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2             3        Huzaifa        Karachi         145   Najam
# 3             4           Asad         Lahore         567   Najam
# 4             5        Hussain      Hyderabad         234   Jawed
# 5            66            Ali      Hyderabad         234  Faisal
# 6            77          Sadaf         Lahore         567  Faisal
# 7            88          Kiran        Karachi         345   Najam
# 8            99            Ali        Karachi         123  Faisal

# %%
#sheet0.merge(sheet2)

# %%
sheet0.merge(sheet2,on='sales_man_name')
# Out:
#    sales_man_id_x sales_man_name sales_man_city_x  product_id_x manager_x  \
# 0               1           Asad          Karachi           123     Jawed
#
#    sales_man_id_y sales_man_city_y  product_id_y manager_y
# 0               4           Lahore           567     Najam

# %%
sheet0.merge(sheet2,on='sales_man_city')
# Out:
#     sales_man_id_x sales_man_name_x sales_man_city  product_id_x manager_x  \
# 0                1             Asad        Karachi           123     Jawed
# 1                1             Asad        Karachi           123     Jawed
# 2                1             Asad        Karachi           123     Jawed
# 3                1             Asad        Karachi           123     Jawed
# 4                3           Farjad        Karachi           145     Najam
# 5                3           Farjad        Karachi           145     Najam
# 6                3           Farjad        Karachi           145     Najam
# 7                3           Farjad        Karachi           145     Najam
# 8                8           Fatima        Karachi           345     Najam
# 9                8           Fatima        Karachi           345     Najam
# 10               8           Fatima        Karachi           345     Najam
# ...

# %%
sheet0.merge(sheet2,on='product_id')
# Out:
#     sales_man_id_x sales_man_name_x sales_man_city_x  product_id manager_x  \
# 0                1             Asad          Karachi         123     Jawed
# 1                1             Asad          Karachi         123     Jawed
# 2                1             Asad          Karachi         123     Jawed
# 3                2           Sumair           Lahore         123     Jawed
# 4                2           Sumair           Lahore         123     Jawed
# 5                2           Sumair           Lahore         123     Jawed
# 6                9         Abdullah          Karachi         123    Faisal
# 7                9         Abdullah          Karachi         123    Faisal
# 8                9         Abdullah          Karachi         123    Faisal
# 9                3           Farjad          Karachi         145     Najam
# 10               4           Hassan           Lahore         567     Najam
# ...

# %%
sheet0.columns = ['Sales_man_id', 'Sales_man_name', 'Sales_man_city', 'Product_id',
       'Manager']

# %%
# No Merging due to change of cloumn name
sheet0.merge(sheet2)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-92-4162dc90612f> in <module>
#       1 # No Merging due to change of cloumn name
# ----> 2 sheet0.merge(sheet2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7332             copy=copy,
#    7333             indicator=indicator,
# -> 7334             validate=validate,
#    7335         )
#    7336
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ...

# %%
# No Merging due to change of cloumn name
sheet0.merge(sheet2,left_on="Sales_man_id", right_on='sales_man_id')
# Out:
#    Sales_man_id Sales_man_name Sales_man_city  Product_id Manager  \
# 0             2         Sumair         Lahore         123   Jawed
# 1             3         Farjad        Karachi         145   Najam
# 2             4         Hassan         Lahore         567   Najam
# 3             5          Nasir      Hyderabad         234   Jawed
#
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             2          Ahmed        Karachi         123   Jawed
# 1             3        Huzaifa        Karachi         145   Najam
# 2             4           Asad         Lahore         567   Najam
# 3             5        Hussain      Hyderabad         234   Jawed

# %%
sheet0
# Out:
#    Sales_man_id Sales_man_name Sales_man_city  Product_id Manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
sheet3
# Out:
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1        Hussain       B    300   450000
# 2            Ali       C    234   125000
# 3           Sana       D    231   652000
# 4         Fatima       E    324   145000
# 5         Kashif       F    123   825000
# 6         Hassan       G    129   125000
# 7          Almas       H    345   325600
# 8          Fahan       I    400   895200

# %%
# When there is no overlapping coloumns we have to provide coloumn names having the same nature of data
sheet0.merge(sheet3,left_on="Sales_man_name", right_on='sales_man_name')
# Out:
#    Sales_man_id Sales_man_name Sales_man_city  Product_id Manager  \
# 0             1           Asad        Karachi         123   Jawed
# 1             4         Hassan         Lahore         567   Najam
# 2             6         Kashif      Hyderabad         234  Faisal
# 3             7           Sana         Lahore         567  Faisal
# 4             8         Fatima        Karachi         345   Najam
#
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1         Hassan       G    129   125000
# 2         Kashif       F    123   825000
# 3           Sana       D    231   652000
# 4         Fatima       E    324   145000

# %%
sheet0.Sales_man_name.apply(lambda name : name.strip())
# Out:
# 0        Asad
# 1      Sumair
# 2      Farjad
# 3      Hassan
# 4       Nasir
# 5      Kashif
# 6        Sana
# 7      Fatima
# 8    Abdullah
# Name: Sales_man_name, dtype: object

# %%
sheet3.sales_man_name.apply(lambda name : name.strip())
# Out:
# 0       Asad
# 1    Hussain
# 2        Ali
# 3       Sana
# 4     Fatima
# 5     Kashif
# 6     Hassan
# 7      Almas
# 8      Fahan
# Name: sales_man_name, dtype: object

# %% [markdown]
# # Repeat Merging Data

# %%
sheet2
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             2          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2             3        Huzaifa        Karachi         145   Najam
# 3             4           Asad         Lahore         567   Najam
# 4             5        Hussain      Hyderabad         234   Jawed
# 5            66            Ali      Hyderabad         234  Faisal
# 6            77          Sadaf         Lahore         567  Faisal
# 7            88          Kiran        Karachi         345   Najam
# 8            99            Ali        Karachi         123  Faisal

# %%
sheet3
# Out:
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1        Hussain       B    300   450000
# 2            Ali       C    234   125000
# 3           Sana       D    231   652000
# 4         Fatima       E    324   145000
# 5         Kashif       F    123   825000
# 6         Hassan       G    129   125000
# 7          Almas       H    345   325600
# 8          Fahan       I    400   895200

# %%
sheet0
# Out:
#    Sales_man_id Sales_man_name Sales_man_city  Product_id Manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
sheet0.merge(sheet2,left_on="Manager", right_on='manager')
# Out:
#     Sales_man_id Sales_man_name Sales_man_city  Product_id Manager  \
# 0              1           Asad        Karachi         123   Jawed
# 1              1           Asad        Karachi         123   Jawed
# 2              1           Asad        Karachi         123   Jawed
# 3              2         Sumair         Lahore         123   Jawed
# 4              2         Sumair         Lahore         123   Jawed
# 5              2         Sumair         Lahore         123   Jawed
# 6              5          Nasir      Hyderabad         234   Jawed
# 7              5          Nasir      Hyderabad         234   Jawed
# 8              5          Nasir      Hyderabad         234   Jawed
# 9              3         Farjad        Karachi         145   Najam
# 10             3         Farjad        Karachi         145   Najam
# 11             3         Farjad        Karachi         145   Najam
# 12             4         Hassan         Lahore         567   Najam
# ...
