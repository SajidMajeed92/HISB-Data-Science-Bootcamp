# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as show
import matplotlib as cm
import matplotlib.colors as colors
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import svm
from mlxtend.plotting import plot_decision_regions

value = 1.5
autism = pd.read_csv('Dataset/10-features-uns.csv')

x = autism.drop(['TARGET'], axis = 1)
y = autism['TARGET']
x_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state=1)

t = np.array(y_train)
t = t.astype(np.integer)
clf_svm = SVC(C=1.3, gamma=0.8, kernel='rbf')
clf_svm.fit(x_train, t)
plt.figure(figsize=[15,10])
plot_decision_regions(X=X_test.values, 
                      y=y_test.values,
                      clf=clf_svm,
                      feature_index=[0,9],
                      filler_feature_values={1:value, 2: value, 3:value, 4:value, 5:value, 6: value, 7:value, 8:value},
                      filler_feature_ranges={1:value, 2: value, 3:value, 4:value, 5:value, 6: value, 7:value, 8:value}, 
                      legend=2)
plt.title('Support Vector Machine')
# Out:
# C:\Users\abc\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   "X does not have valid feature names, but"
# C:\ProgramData\Anaconda3\lib\site-packages\mlxtend\plotting\decision_regions.py:315: UserWarning: No contour levels were found within the data range.
#   ax.contour(xx, yy, Z, cset.levels, **contour_kwargs)
# Text(0.5, 1.0, 'Support Vector Machine')
