# %%
import pandas as pd
import numpy as np

# %%
car_data = pd.read_csv('car_data.csv')

# %%
car_data.shape
# Out:
# (892, 6)

# %%
car_data.sample(10)
# Out:
#                                name   company  year      Price  kms_driven  \
# 359  Mahindra Bolero Power Plus SLE  Mahindra  2018   6,99,000   1,800 kms
# 84                       Honda Brio     Honda  2012   2,24,999  30,000 kms
# 254   Tata Sumo Gold Select Variant      Tata  2013   3,00,000  50,000 kms
# 541           Maruti Suzuki Wagon R    Maruti  2009   1,60,000  35,000 kms
# 275            Renault Kwid RXT Opt   Renault  2018   3,25,000  15,000 kms
# 477  Maruti Suzuki Baleno Delta 1.2    Maruti  2016   4,98,000  22,000 kms
# 563             Mahindra XUV500 W10  Mahindra  2018  12,99,000  40,000 kms
# 761          Tata Tiago Revotron XM      Tata  2018   4,30,000   3,500 kms
# 164          Hyundai i10 Sportz 1.2   Hyundai  2010   1,68,000  45,872 kms
# 191     Maruti Suzuki Ciaz VXi Plus    Maruti  2016   7,00,000   3,350 kms
#
#     fuel_type
# 359    Diesel
# 84     Petrol
# 254    Diesel
# 541    Petrol
# 275    Petrol
# 477    Petrol
# 563    Diesel
# 761    Petrol
# ...

# %%
car_data.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
# name          892 non-null object
# company       892 non-null object
# year          892 non-null object
# Price         892 non-null object
# kms_driven    840 non-null object
# fuel_type     837 non-null object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %% [markdown]
# ### Missing Values

# %%
car_data.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
# car_data.notna().sum()

# %%
# car_data.isnull().sum()

# %%
# car_data.notnull().sum()

# %%
# dropp missing value records
car_data.dropna(inplace=True)
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 837 entries, 0 to 889
# Data columns (total 6 columns):
# name          837 non-null object
# company       837 non-null object
# year          837 non-null object
# Price         837 non-null object
# kms_driven    837 non-null object
# fuel_type     837 non-null object
# dtypes: object(6)
# memory usage: 45.8+ KB

# %% [markdown]
# ### Duplicate Records

# %%
car_data.duplicated().sum()
# Out:
# 92

# %%
car_data.drop_duplicates(inplace=True)

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 745 entries, 0 to 889
# Data columns (total 6 columns):
# name          745 non-null object
# company       745 non-null object
# year          745 non-null object
# Price         745 non-null object
# kms_driven    745 non-null object
# fuel_type     745 non-null object
# dtypes: object(6)
# memory usage: 40.7+ KB

# %%
car_data.name.unique()
# Out:
# array(['Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Maruti Suzuki Alto 800 Vxi',
#        'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#        'Ford EcoSport Titanium 1.5L TDCi', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente 1.5L TDCi',
#        'Maruti Suzuki Alto K10 VXi AMT', 'Skoda Fabia Classic 1.2 MPI',
#        'Maruti Suzuki Stingray VXi', 'Hyundai Elite i20 Magna 1.2',
#        'Mahindra Scorpio SLE BS IV', 'Audi A8', 'Audi Q7',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto 800',
#        'Hyundai i20 Sportz 1.2', 'Maruti Suzuki Alto 800 Lx',
#        'Maruti Suzuki Vitara Brezza ZDi', 'Maruti Suzuki Alto LX',
#        'Mahindra Bolero DI', 'Maruti Suzuki Swift Dzire ZDi',
#        'Mahindra Scorpio S10 4WD', 'Maruti Suzuki Swift Vdi BSIII',
#        'Maruti Suzuki Wagon R VXi BS III',
#        'Maruti Suzuki Wagon R VXi Minor',
#        'Toyota Innova 2.0 G 8 STR BS IV', 'Renault Lodgy 85 PS RXL',
# ...

# %%
car_data.name = car_data.name.str.split().str[:3].str.join(' ')
car_data.sample(10)
# Out:
#                       name    company  year          Price  kms_driven  \
# 619     Maruti Suzuki Alto     Maruti  2002  Ask For Price  56,000 kms
# 287      Chevrolet Beat LS  Chevrolet  2010         80,000  56,000 kms
# 200    Maruti Suzuki Wagon     Maruti  2011       2,10,000  35,000 kms
# 402             Honda City      Honda  2000         65,000  80,000 kms
# 718      Maruti Suzuki SX4     Maruti  2016       9,70,000  85,960 kms
# 605     Maruti Suzuki Alto     Maruti  2017       3,60,000   9,400 kms
# 420      Renault Duster 85    Renault  2015       7,15,000  65,000 kms
# 396    Maruti Suzuki Versa     Maruti  2004         80,000  50,000 kms
# 629    Maruti Suzuki Swift     Maruti  2011       2,55,000  64,000 kms
# 559  Hyundai Verna Fluidic    Hyundai  2015       4,30,000  73,000 kms
#
#     fuel_type
# 619    Petrol
# 287    Petrol
# 200    Petrol
# 402    Petrol
# 718    Diesel
# 605    Petrol
# 420    Diesel
# 396    Petrol
# 629    Petrol
# 559    Diesel

# %%
car_data.company
# Out:
# 0       Hyundai
# 1      Mahindra
# 2        Maruti
# 3       Hyundai
# 4          Ford
#          ...
# 883      Maruti
# 885        Tata
# 886      Toyota
# 888        Tata
# 889    Mahindra
# Name: company, Length: 745, dtype: object

# %%
car_data.company.unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Maruti', 'Ford', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat', 'Force',
#        'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'], dtype=object)

# %%
car_data.year
# Out:
# 0      2007
# 1      2006
# 2      2018
# 3      2014
# 4      2014
#        ...
# 883    2011
# 885    2009
# 886    2009
# 888    2018
# 889    2013
# Name: year, Length: 745, dtype: object

# %%
car_data.year.unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '2003', '2004', '1995', '2002', '2001'], dtype=object)

# %%
car_data.year = pd.to_datetime(car_data.year)
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 745 entries, 0 to 889
# Data columns (total 6 columns):
# name          745 non-null object
# company       745 non-null object
# year          745 non-null datetime64[ns]
# Price         745 non-null object
# kms_driven    745 non-null object
# fuel_type     745 non-null object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 40.7+ KB

# %%
car_data.Price
# Out:
# 0             80,000
# 1           4,25,000
# 2      Ask For Price
# 3           3,25,000
# 4           5,75,000
#            ...
# 883         2,70,000
# 885         1,10,000
# 886         3,00,000
# 888         2,60,000
# 889         3,90,000
# Name: Price, Length: 745, dtype: object

# %%
car_data.Price.unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
car_data.Price.value_counts()
# Out:
# Ask For Price    21
# 2,50,000         13
# 1,30,000         11
# 3,50,000         11
# 1,20,000         10
#                  ..
# 9,70,000          1
# 10,65,000         1
# 5,19,000          1
# 4,48,000          1
# 6,15,000          1
# Name: Price, Length: 273, dtype: int64

# %%
car_data = car_data[car_data.Price!="Ask For Price"]

# %%
car_data.Price.unique()
# Out:
# array(['80,000', '4,25,000', '3,25,000', '5,75,000', '1,75,000',
#        '1,90,000', '8,30,000', '2,50,000', '1,82,000', '3,15,000',
#        '4,15,000', '3,20,000', '10,00,000', '5,00,000', '3,50,000',
#        '1,60,000', '3,10,000', '75,000', '1,00,000', '2,90,000', '95,000',
#        '1,80,000', '3,85,000', '1,05,000', '6,50,000', '6,89,999',
#        '4,48,000', '5,49,000', '5,01,000', '4,89,999', '2,80,000',
#        '3,49,999', '2,84,999', '3,45,000', '4,99,999', '2,35,000',
#        '2,49,999', '14,75,000', '3,95,000', '2,20,000', '1,70,000',
#        '85,000', '2,00,000', '5,70,000', '1,10,000', '4,48,999',
#        '18,91,111', '1,59,500', '3,44,999', '4,49,999', '8,65,000',
#        '6,99,000', '3,75,000', '2,24,999', '12,00,000', '1,95,000',
#        '3,51,000', '2,40,000', '90,000', '1,55,000', '6,00,000',
#        '1,89,500', '2,10,000', '3,90,000', '1,35,000', '16,00,000',
#        '7,01,000', '2,65,000', '5,25,000', '3,72,000', '6,35,000',
# ...

# %%
car_data.Price.astype('int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-6569cfd71d01> in <module>
# ----> 1 car_data.Price.astype('int32')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
car_data.Price = car_data.Price.str.replace(",",'').astype('int32')
car_data.Price
# Out:
# 0       80000
# 1      425000
# 3      325000
# 4      575000
# 6      175000
#         ...
# 883    270000
# 885    110000
# 886    300000
# 888    260000
# 889    390000
# Name: Price, Length: 724, dtype: int32

# %%
car_data.kms_driven.unique()
# Out:
# array(['45,000 kms', '40 kms', '28,000 kms', '36,000 kms', '41,000 kms',
#        '25,000 kms', '24,530 kms', '60,000 kms', '30,000 kms',
#        '32,000 kms', '48,660 kms', '4,000 kms', '16,934 kms',
#        '43,000 kms', '35,550 kms', '39,522 kms', '39,000 kms',
#        '55,000 kms', '72,000 kms', '15,975 kms', '70,000 kms',
#        '23,452 kms', '35,522 kms', '48,508 kms', '15,487 kms',
#        '82,000 kms', '20,000 kms', '68,000 kms', '38,000 kms',
#        '27,000 kms', '33,000 kms', '46,000 kms', '16,000 kms',
#        '47,000 kms', '35,000 kms', '30,874 kms', '15,000 kms',
#        '29,685 kms', '1,30,000 kms', '19,000 kms', '54,000 kms',
#        '13,000 kms', '38,200 kms', '22,000 kms', '50,000 kms',
#        '13,500 kms', '3,600 kms', '45,863 kms', '60,500 kms',
#        '12,500 kms', '18,000 kms', '13,349 kms', '29,000 kms',
#        '44,000 kms', '42,000 kms', '14,000 kms', '49,000 kms',
#        '36,200 kms', '51,000 kms', '1,04,000 kms', '33,333 kms',
# ...

# %%
car_data.kms_driven = car_data.kms_driven.str.replace(",","").str.replace(" kms","").astype('float64')

# %%
car_data.fuel_type
# Out:
# 0      Petrol
# 1      Diesel
# 3      Petrol
# 4      Diesel
# 6      Diesel
#         ...
# 883    Petrol
# 885    Diesel
# 886    Petrol
# 888    Diesel
# 889    Diesel
# Name: fuel_type, Length: 724, dtype: object

# %%
car_data.fuel_type.unique()
# Out:
# array(['Petrol', 'Diesel', 'LPG'], dtype=object)

# %%
car_data
# Out:
#                        name   company       year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai 2007-01-01   80000     45000.0    Petrol
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01  425000        40.0    Diesel
# 3         Hyundai Grand i10   Hyundai 2014-01-01  325000     28000.0    Petrol
# 4    Ford EcoSport Titanium      Ford 2014-01-01  575000     36000.0    Diesel
# 6                 Ford Figo      Ford 2012-01-01  175000     41000.0    Diesel
# ..                      ...       ...        ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti 2011-01-01  270000     50000.0    Petrol
# 885          Tata Indica V2      Tata 2009-01-01  110000     30000.0    Diesel
# 886    Toyota Corolla Altis    Toyota 2009-01-01  300000    132000.0    Petrol
# 888            Tata Zest XM      Tata 2018-01-01  260000     27000.0    Diesel
# 889      Mahindra Quanto C8  Mahindra 2013-01-01  390000     40000.0    Diesel
#
# [724 rows x 6 columns]

# %%
car_data.reset_index(drop=True,inplace=True)

# %%
car_data.to_csv("Cleaned_Car_Data")

# %%
car_data
# Out:
#                        name   company       year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai 2007-01-01   80000     45000.0    Petrol
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01  425000        40.0    Diesel
# 2         Hyundai Grand i10   Hyundai 2014-01-01  325000     28000.0    Petrol
# 3    Ford EcoSport Titanium      Ford 2014-01-01  575000     36000.0    Diesel
# 4                 Ford Figo      Ford 2012-01-01  175000     41000.0    Diesel
# ..                      ...       ...        ...     ...         ...       ...
# 719      Maruti Suzuki Ritz    Maruti 2011-01-01  270000     50000.0    Petrol
# 720          Tata Indica V2      Tata 2009-01-01  110000     30000.0    Diesel
# 721    Toyota Corolla Altis    Toyota 2009-01-01  300000    132000.0    Petrol
# 722            Tata Zest XM      Tata 2018-01-01  260000     27000.0    Diesel
# 723      Mahindra Quanto C8  Mahindra 2013-01-01  390000     40000.0    Diesel
#
# [724 rows x 6 columns]

# %%
# Which is the most expensive car in our data. 
# Which is the most cheap car in our data.

# %%
maxPrice = car_data.Price.max()

# %%
car_data [car_data.Price == car_data.Price.max()]['name'].values[0]
# Out:
# 'Mahindra XUV500 W6'

# %%
car_data [car_data.Price == car_data.Price.min()]['name'].values
# Out:
# array(['Maruti Suzuki Maruti', 'Maruti Suzuki 800'], dtype=object)

# %%
# # which is the most demanded brand top 3  
car_data.company.value_counts().head(3)
## or 
car_data.company.value_counts()[:3].index
# Out:
# Index(['Maruti', 'Hyundai', 'Mahindra'], dtype='object')

# %%
# # which is the least demanded brand top 3  
car_data.company.value_counts(ascending=True)
## or 
car_data.company.value_counts(ascending=True)[:3]
# Out:
# Jeep     1
# Land     1
# Volvo    1
# Name: company, dtype: int64

# %%
car_data.Price.mean()
# Out:
# 403245

# %%
car_data.Price.min()
# Out:
# 30000

# %%
car_data.Price.max()
# Out:
# 8500003

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(car_data.name, car_data.Price)
plt.show()

# %%
a = np.array([9,13,10,12,54,12,10,9,7,60])

# %%
a.mean()
# Out:
# 19.6

# %%
np.sort(a)
# Out:
# array([ 7,  9,  9, 10, 10, 12, 12, 13, 54, 60])

# %%
(10+12)/2
# Out:
# 11.0

# %%
np.median(a)
# Out:
# 11.0

# %%
def category(price):
    if price > car_data.Price.median():
        return "Expensive"
    else:
        return "Cheap"

# %%
car_data['Category'] = car_data.Price.apply(category)

# %%
car_data
# Out:
#                        name   company       year   Price  kms_driven  \
# 0       Hyundai Santro Xing   Hyundai 2007-01-01   80000     45000.0
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01  425000        40.0
# 2         Hyundai Grand i10   Hyundai 2014-01-01  325000     28000.0
# 3    Ford EcoSport Titanium      Ford 2014-01-01  575000     36000.0
# 4                 Ford Figo      Ford 2012-01-01  175000     41000.0
# ..                      ...       ...        ...     ...         ...
# 719      Maruti Suzuki Ritz    Maruti 2011-01-01  270000     50000.0
# 720          Tata Indica V2      Tata 2009-01-01  110000     30000.0
# 721    Toyota Corolla Altis    Toyota 2009-01-01  300000    132000.0
# 722            Tata Zest XM      Tata 2018-01-01  260000     27000.0
# 723      Mahindra Quanto C8  Mahindra 2013-01-01  390000     40000.0
#
#     fuel_type   Category Category_by_lambda
# 0      Petrol      Cheap              Cheap
# 1      Diesel  Expensive          Expensive
# ...

# %%
car_data['Category_by_lambda'] = car_data.Price.apply(lambda p:"Expensive" if p>car_data.Price.median() else "Cheap")

# %%
car_data
# Out:
#                        name   company       year   Price  kms_driven  \
# 0       Hyundai Santro Xing   Hyundai 2007-01-01   80000     45000.0
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01  425000        40.0
# 2         Hyundai Grand i10   Hyundai 2014-01-01  325000     28000.0
# 3    Ford EcoSport Titanium      Ford 2014-01-01  575000     36000.0
# 4                 Ford Figo      Ford 2012-01-01  175000     41000.0
# ..                      ...       ...        ...     ...         ...
# 719      Maruti Suzuki Ritz    Maruti 2011-01-01  270000     50000.0
# 720          Tata Indica V2      Tata 2009-01-01  110000     30000.0
# 721    Toyota Corolla Altis    Toyota 2009-01-01  300000    132000.0
# 722            Tata Zest XM      Tata 2018-01-01  260000     27000.0
# 723      Mahindra Quanto C8  Mahindra 2013-01-01  390000     40000.0
#
#     fuel_type   Category Category_by_lambda
# 0      Petrol      Cheap              Cheap
# 1      Diesel  Expensive          Expensive
# ...

# %% [markdown]
# # Data Wrangling

# %%
df0 = pd.read_excel('test_data.xlsx',sheet_name=0)
df1 = pd.read_excel('test_data.xlsx',sheet_name=1)
df2 = pd.read_excel('test_data.xlsx',sheet_name=2)
df3 = pd.read_excel('test_data.xlsx',sheet_name=3,header=None)

# %%
df0
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
df1
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager
# 0             11          Ahmed        Karachi         123   Jawed
# 1             22           Umer         Lahore         123   Jawed
# 2             33        Huzaifa        Karachi         145   Najam
# 3             44           Asad         Lahore         567   Najam
# 4             55        Hussain      Hyderabad         234   Jawed
# 5             66            Ali      Hyderabad         234  Faisal
# 6             77          Sadaf         Lahore         567  Faisal
# 7             88          Kiran        Karachi         345   Najam
# 8             99            Ali        Karachi         123  Faisal
# 9              6         Kashif      Hyderabad         234  Faisal
# 10             7           Sana         Lahore         567  Faisal
# 11             8         Fatima        Karachi         345   Najam
# 12             9       Abdullah        Karachi         123  Faisal

# %%
df2
# Out:
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1        Hussain       B    300   450000
# 2            Ali       C    234   125000
# 3           Sana       D    231   652000
# 4         Fatima       E    324   145000
# 5         Kashif       F    123   825000
# 6         Hassan       G    129   125000
# 7          Almas       H    345   325600
# 8          Fahan       I    400   895200

# %%
newdf = pd.concat([df0,df1])
newdf.reset_index(drop=True,inplace=True)
newdf
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager
# 0              1           Asad        Karachi         123   Jawed
# 1              2         Sumair         Lahore         123   Jawed
# 2              3         Farjad        Karachi         145   Najam
# 3              4         Hassan         Lahore         567   Najam
# 4              5          Nasir      Hyderabad         234   Jawed
# 5              6         Kashif      Hyderabad         234  Faisal
# 6              7           Sana         Lahore         567  Faisal
# 7              8         Fatima        Karachi         345   Najam
# 8              9       Abdullah        Karachi         123  Faisal
# 9             11          Ahmed        Karachi         123   Jawed
# 10            22           Umer         Lahore         123   Jawed
# 11            33        Huzaifa        Karachi         145   Najam
# 12            44           Asad         Lahore         567   Najam
# ...

# %%
newdf = pd.concat([df0,df1],axis=1)
# newdf.reset_index(drop=True,inplace=True)
newdf
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager  \
# 0            1.0           Asad        Karachi       123.0   Jawed
# 1            2.0         Sumair         Lahore       123.0   Jawed
# 2            3.0         Farjad        Karachi       145.0   Najam
# 3            4.0         Hassan         Lahore       567.0   Najam
# 4            5.0          Nasir      Hyderabad       234.0   Jawed
# 5            6.0         Kashif      Hyderabad       234.0  Faisal
# 6            7.0           Sana         Lahore       567.0  Faisal
# 7            8.0         Fatima        Karachi       345.0   Najam
# 8            9.0       Abdullah        Karachi       123.0  Faisal
# 9            NaN            NaN            NaN         NaN     NaN
# 10           NaN            NaN            NaN         NaN     NaN
# 11           NaN            NaN            NaN         NaN     NaN
# 12           NaN            NaN            NaN         NaN     NaN
#
# ...

# %%
df2
# Out:
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1        Hussain       B    300   450000
# 2            Ali       C    234   125000
# 3           Sana       D    231   652000
# 4         Fatima       E    324   145000
# 5         Kashif       F    123   825000
# 6         Hassan       G    129   125000
# 7          Almas       H    345   325600
# 8          Fahan       I    400   895200

# %%
pd.concat([df1,df2])
# Out:
# C:\Users\Nasir Hussain\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#      Amount  Region   Sales manager  product_id sales_man_city  sales_man_id  \
# 0        NaN     NaN    NaN   Jawed       123.0        Karachi          11.0
# 1        NaN     NaN    NaN   Jawed       123.0         Lahore          22.0
# 2        NaN     NaN    NaN   Najam       145.0        Karachi          33.0
# 3        NaN     NaN    NaN   Najam       567.0         Lahore          44.0
# 4        NaN     NaN    NaN   Jawed       234.0      Hyderabad          55.0
# 5        NaN     NaN    NaN  Faisal       234.0      Hyderabad          66.0
# ...

# %%
df0
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
df1
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager
# 0             11          Ahmed        Karachi         123   Jawed
# 1             22           Umer         Lahore         123   Jawed
# 2             33        Huzaifa        Karachi         145   Najam
# 3             44           Asad         Lahore         567   Najam
# 4             55        Hussain      Hyderabad         234   Jawed
# 5             66            Ali      Hyderabad         234  Faisal
# 6             77          Sadaf         Lahore         567  Faisal
# 7             88          Kiran        Karachi         345   Najam
# 8             99            Ali        Karachi         123  Faisal
# 9              6         Kashif      Hyderabad         234  Faisal
# 10             7           Sana         Lahore         567  Faisal
# 11             8         Fatima        Karachi         345   Najam
# 12             9       Abdullah        Karachi         123  Faisal

# %%
df0.merge(df1)
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             6         Kashif      Hyderabad         234  Faisal
# 1             7           Sana         Lahore         567  Faisal
# 2             8         Fatima        Karachi         345   Najam
# 3             9       Abdullah        Karachi         123  Faisal

# %%
df0.merge(df1,on='sales_man_name')
# Out:
#    sales_man_id_x sales_man_name sales_man_city_x  product_id_x manager_x  \
# 0               1           Asad          Karachi           123     Jawed
# 1               6         Kashif        Hyderabad           234    Faisal
# 2               7           Sana           Lahore           567    Faisal
# 3               8         Fatima          Karachi           345     Najam
# 4               9       Abdullah          Karachi           123    Faisal
#
#    sales_man_id_y sales_man_city_y  product_id_y manager_y
# 0              44           Lahore           567     Najam
# 1               6        Hyderabad           234    Faisal
# 2               7           Lahore           567    Faisal
# 3               8          Karachi           345     Najam
# 4               9          Karachi           123    Faisal

# %%
df0.merge(df1,on='sales_man_city')
# Out:
#     sales_man_id_x sales_man_name_x sales_man_city  product_id_x manager_x  \
# 0                1             Asad        Karachi           123     Jawed
# 1                1             Asad        Karachi           123     Jawed
# 2                1             Asad        Karachi           123     Jawed
# 3                1             Asad        Karachi           123     Jawed
# 4                1             Asad        Karachi           123     Jawed
# 5                1             Asad        Karachi           123     Jawed
# 6                3           Farjad        Karachi           145     Najam
# 7                3           Farjad        Karachi           145     Najam
# 8                3           Farjad        Karachi           145     Najam
# 9                3           Farjad        Karachi           145     Najam
# 10               3           Farjad        Karachi           145     Najam
# ...

# %%
df0.columns  =['Sales_man_id', 'Sales_man_name', 'Sales_man_city', 'Product_id',
       'Manager']

# %%
df1.columns
# Out:
# Index(['sales_man_id', 'sales_man_name', 'sales_man_city', 'product_id',
#        'manager'],
#       dtype='object')

# %%
df0.merge(df1)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-180-b5db4788412f> in <module>
# ----> 1 df0.merge(df1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7332             copy=copy,
#    7333             indicator=indicator,
# -> 7334             validate=validate,
#    7335         )
#    7336
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ...

# %%
df0.merge(df1,left_on='Sales_man_id', right_on='sales_man_id')
# Out:
#    Sales_man_id Sales_man_name Sales_man_city  Product_id Manager  \
# 0             6         Kashif      Hyderabad         234  Faisal
# 1             7           Sana         Lahore         567  Faisal
# 2             8         Fatima        Karachi         345   Najam
# 3             9       Abdullah        Karachi         123  Faisal
#
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             6         Kashif      Hyderabad         234  Faisal
# 1             7           Sana         Lahore         567  Faisal
# 2             8         Fatima        Karachi         345   Najam
# 3             9       Abdullah        Karachi         123  Faisal

# %%
df0.merge(df2,left_on='Sales_man_name',right_on="sales_man_name")
# Out:
#    Sales_man_id Sales_man_name Sales_man_city  Product_id Manager  \
# 0             1           Asad        Karachi         123   Jawed
# 1             4         Hassan         Lahore         567   Najam
# 2             6         Kashif      Hyderabad         234  Faisal
# 3             7           Sana         Lahore         567  Faisal
# 4             8         Fatima        Karachi         345   Najam
#
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1         Hassan       G    129   125000
# 2         Kashif       F    123   825000
# 3           Sana       D    231   652000
# 4         Fatima       E    324   145000

# %%
df0
# Out:
#    Sales_man_id Sales_man_name Sales_man_city  Product_id Manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
df2
# Out:
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1        Hussain       B    300   450000
# 2            Ali       C    234   125000
# 3           Sana       D    231   652000
# 4         Fatima       E    324   145000
# 5         Kashif       F    123   825000
# 6         Hassan       G    129   125000
# 7          Almas       H    345   325600
# 8          Fahan       I    400   895200

# %%
df0.Sales_man_name = df0.Sales_man_name.apply(lambda name: name.strip())

# %% [markdown]
# # Repeat Merging Data

# %%
df0
# Out:
#    Sales_man_id Sales_man_name Sales_man_city  Product_id Manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
df1
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager
# 0             11          Ahmed        Karachi         123   Jawed
# 1             22           Umer         Lahore         123   Jawed
# 2             33        Huzaifa        Karachi         145   Najam
# 3             44           Asad         Lahore         567   Najam
# 4             55        Hussain      Hyderabad         234   Jawed
# 5             66            Ali      Hyderabad         234  Faisal
# 6             77          Sadaf         Lahore         567  Faisal
# 7             88          Kiran        Karachi         345   Najam
# 8             99            Ali        Karachi         123  Faisal
# 9              6         Kashif      Hyderabad         234  Faisal
# 10             7           Sana         Lahore         567  Faisal
# 11             8         Fatima        Karachi         345   Najam
# 12             9       Abdullah        Karachi         123  Faisal

# %%
df0.merge(df1)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-189-b5db4788412f> in <module>
# ----> 1 df0.merge(df1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7332             copy=copy,
#    7333             indicator=indicator,
# -> 7334             validate=validate,
#    7335         )
#    7336
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ...

# %%
# where there is no overlapping columns
# we provide the column name to merge (but data must be of same nature)
df0.merge(df1,left_on='Sales_man_name', right_on='sales_man_name')
# Out:
#    Sales_man_id Sales_man_name Sales_man_city  Product_id Manager  \
# 0             1           Asad        Karachi         123   Jawed
# 1             6         Kashif      Hyderabad         234  Faisal
# 2             7           Sana         Lahore         567  Faisal
# 3             8         Fatima        Karachi         345   Najam
# 4             9       Abdullah        Karachi         123  Faisal
#
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0            44           Asad         Lahore         567   Najam
# 1             6         Kashif      Hyderabad         234  Faisal
# 2             7           Sana         Lahore         567  Faisal
# 3             8         Fatima        Karachi         345   Najam
# 4             9       Abdullah        Karachi         123  Faisal

# %%
df0.columns = ['sales_man_id', 'Sales_man_name', 'Sales_man_city', 'Product_id',
       'Manager']

# %%
df0
# Out:
#    sales_man_id Sales_man_name Sales_man_city  Product_id Manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
df0.merge(df1)
# Out:
#    sales_man_id Sales_man_name Sales_man_city  Product_id Manager  \
# 0             6         Kashif      Hyderabad         234  Faisal
# 1             7           Sana         Lahore         567  Faisal
# 2             8         Fatima        Karachi         345   Najam
# 3             9       Abdullah        Karachi         123  Faisal
#
#   sales_man_name sales_man_city  product_id manager
# 0         Kashif      Hyderabad         234  Faisal
# 1           Sana         Lahore         567  Faisal
# 2         Fatima        Karachi         345   Najam
# 3       Abdullah        Karachi         123  Faisal

# %% [markdown]
# ![outermerge.png](attachment:outermerge.png)
